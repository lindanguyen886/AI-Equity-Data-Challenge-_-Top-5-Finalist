# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
ep =pd.read_csv('/content/Employment Projections.csv')

# %%
ep.head()
# Out:
#                                     Occupation Title Occupation Code  \
# 0  Accountants and auditors    * Account Auditor*...      ="13-2011"
# 1  Actors    * Actor Understudy* Actress* Dramati...      ="27-2011"
# 2  Actuaries    * Actuarial Associate* Actuarial ...      ="15-2011"
# 3  Acupuncturists    * Acupuncture Physician* Lic...      ="29-1291"
# 4  Adhesive bonding machine operators and tenders...      ="51-9191"
#
#   Employment 2024 Employment 2034  Employment Change, 2024-2034  \
# 0         1,579.8         1,652.6                          72.8
# 1            57.0            57.1                           0.2
# 2            33.6            40.9                           7.3
# 3            15.3            16.4                           1.0
# 4            12.2            12.3                           0.1
#
#    Employment Percent Change, 2024-2034  \
# 0                                   4.6
# 1                                   0.3
# ...

# %%
 ep = ep.drop(columns =['Occupation Code', 'Employment 2024', 'Employment 2034', 'Employment Change, 2024-2034', 'Education Code', 'Work Experience in a Related Occupation', 'Workex Code', 'trCode'])

# %%
ep_complete = ep.copy()
ep_complete['Occupation Type'] = ep_complete['Occupation Title'].str.split(' \* ').str[0]
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\*'
# <>:2: SyntaxWarning: invalid escape sequence '\*'
# /tmp/ipython-input-834820692.py:2: SyntaxWarning: invalid escape sequence '\*'
#   ep_complete['Occupation Type'] = ep_complete['Occupation Title'].str.split(' \* ').str[0]

# %%
ep_complete
# Out:
#                                       Occupation Title  \
# 0    Accountants and auditors    * Account Auditor*...
# 1    Actors    * Actor Understudy* Actress* Dramati...
# 2    Actuaries    * Actuarial Associate* Actuarial ...
# 3    Acupuncturists    * Acupuncture Physician* Lic...
# 4    Adhesive bonding machine operators and tenders...
# ..                                                 ...
# 827  Woodworkers, all other    * Pole Framer* Timbe...
# 828  Woodworking machine setters, operators, and te...
# 829  Word processors and typists    * Clerk Typist*...
# 830  Writers and authors    * Advertising Copy Writ...
# 831  Zoologists and wildlife biologists    * Aquati...
#
#      Employment Percent Change, 2024-2034  \
# 0                                     4.6
# 1                                     0.3
# 2                                    21.8
# 3                                     6.8
# 4                                     1.0
# ..                                    ...
# ...

# %%
ep_complete.insert(0, 'Occupation Type', ep_complete.pop('Occupation Type'))

# %%
ep_complete = ep_complete.drop(columns = ['Occupation Title'])

# %%
ep_complete = ep_complete.set_index('Occupation Type')

# %%
print(ep_complete.index)
# Out:
# Index(['Accountants and auditors   ', 'Actors   ', 'Actuaries   ',
#        'Acupuncturists   ',
#        'Adhesive bonding machine operators and tenders   ',
#        'Administrative law judges, adjudicators, and hearing officers   ',
#        'Administrative services managers   ',
#        'Adult basic education, adult secondary education, and english as a second language instructors   ',
#        'Advertising and promotions managers   ', 'Advertising sales agents   ',
#        ...
#        'Weighers, measurers, checkers, and samplers, recordkeeping   ',
#        'Welders, cutters, solderers, and brazers   ',
#        'Welding, soldering, and brazing machine setters, operators, and tenders   ',
#        'Wellhead pumpers   ', 'Wind turbine service technicians   ',
#        'Woodworkers, all other   ',
#        'Woodworking machine setters, operators, and tenders, except sawing   ',
#        'Word processors and typists   ', 'Writers and authors   ',
# ...

# %%
ep_complete
# Out:
#                                                     Employment Percent Change, 2024-2034  \
# Occupation Type
# Accountants and auditors                                                             4.6
# Actors                                                                               0.3
# Actuaries                                                                           21.8
# Acupuncturists                                                                       6.8
# Adhesive bonding machine operators and tenders                                       1.0
# ...                                                                                  ...
# Woodworkers, all other                                                              -4.4
# Woodworking machine setters, operators, and ten...                                  -1.8
# Word processors and typists                                                        -36.1
# ...

# %%
ep_complete.loc['Telemarketers   ']
# Out:
# Employment Percent Change, 2024-2034                                          -22.1
# Occupational Openings, 2024-2034 Annual Average                                 6.5
# Median Annual Wage 2024                                                      34,410
# Typical Entry-Level Education                      No formal educational credential
# Typical on-the-job Training                          Short-term on-the-job training
# Name: Telemarketers   , dtype: object

# %%
job_AI = pd.DataFrame({
    'Occupation Title': [
        'Big Data Specialist',
        'FinTech Engineers',
        'AI and Machine Learning Specialist',
        'Software and Application Developers',
        'Security Management Specialists',
        'Data Warehousing Specialists',
        'Autonomous and Electric Vehicle Specialists',
        'UI and UX Designers',
        'Light Truck or Delivery Service Drivers',
        'Internet of Things Specialists',
        'Data Analysts and Scientists',
        'Environmental Engineers',
        'Information Security Analysts',
        'Develop Engineer',
        'Renewable Energy Engineers',
        'Postal Service Clerks',
        'Bank Tellers and Related Clerks',
        'Data Entry Clerks',
        'Cashiers and Ticket Clerks',
        'Administrative Assistants and Executive Secretaries',
        'Printing and Related Trades Workers',
        'Accounting, Bookkeeping and Payroll Clerks',
        'Material-Recording and Stock-Keeping Clerks',
        'Transportation Attendants and Conductors',
        'Door-To-Door Sales Workers',
        'Graphic Designers',
        'Claims Adjusters, Examiners and Investigators',
        'Legal Officials',
        'Legal Secretaries',
        'Telemarketers'
    ],
    'Employment Percent Change, 2024-2034':[
        33.5,
        15.8,
        38,
        15.8,
        28.5,
        8.7,
        -13.6,
        7.0,
        7.3,
        11.9,
        33.5,
        3.9,
        28.5,
        15.8,
        3.9,
        -3.5,
        -5.5,
        -25.9,
        -9.9,
        -1.6,
        -8.1,
        -5.8,
        8.5,
        1.1,
        -10.0,
        2.1,
        -5.1,
        -5.8,
        -5.8,
        -22.1










    ],
    'Occupational Openings, 2024-2034 Annual Average':[
        23.4,
        115.2,
        np.nan,
        115.2,
        16.0,
        4.0,
        0.6,
        9.1,
        120.2,
        11.2,
        23.4,
        3.0,
        16.0,
        115.2,
        3.0,
        6.1,
        341.7,
        9.5,
        542.6,
        50.0,
        13.7,
        170.0,
        472.3,
        3.1,
        2.7,
        20.0,
        21.1,
        19.6,
        19.6,
        6.5


    ],

    'Median Annual Wage 2024': [
        112590,
        133080,
        168730,
        133080,
        124910,
        135980,
        47940,
        98090,
        44140,
        130390,
        112590,
        104170,
        124910,
        133080,
        104170,
        61630,
        42830,
        39850,
        31190,
        74260,
        45160,
        49210,
        37090,
        74080,
        34530,
        61300,
        76790,
        54140,
        54140,
        34410

    ],

    'Typical Entry-Level Education': [
        "Bachelor's Degree",
        "Bachelor's Degree",
        "Bachelor's Degree",
        "Bachelor's Degree",
        "Bachelor's Degree",
        "Bachelor's Degree",
        "High school diploma or equivalent",
        "Bachelor's degree",
        "High school diploma or equivalent",
        "Bachelor's degree",
        "Bachelor's degree",
        "Bachelor's degree",
        "Bachelor's degree",
        "Bachelor's degree",
        "Bachelor's degree",
        "No formal educational credential",
        "High school diploma or equivalent",
        "High school diploma or equivalent",
        "No formal educational credential",
        "High school diploma or equivalent",
        "High school diploma or equivalent",
        "Some college, no degree",
        "No formal educational credential",
        "High school diploma or equivalent",
        "No formal educational credential",
        "Bachelor's degree",
        "High school diploma or equivalent",
        "High school diploma or equivalent",
        "High school diploma or equivalent",
        "No formal educational credential",

    ],

    'Typical on-the-job Training':[
        np.nan,
        np.nan,
        np.nan,
        np.nan,
        np.nan,
        np.nan,
        "Moderate-term on-the-job training",
        np.nan,
        "Short-term on-the-job training",
        np.nan,
        np.nan,
        np.nan,
        np.nan,
        np.nan,
        np.nan,
        "Short-term on-the-job training",
        "Short-term on-the-job training",
        "Short-term on-the-job training",
        "Short-term on-the-job training",
        np.nan,
        "Moderate-term on-the-job training",
        "Moderate-term on-the-job training",
        "Short-term on-the-job training",
        "Moderate-term on-the-job training",
        "Short-term on-the-job training",
        np.nan,
        "Long-term on-the-job training",
        "Moderate-term on-the-job training",
        "Moderate-term on-the-job training",
        "Short-term on-the-job training",



    ],
    'AI Influence (Net Growth %)': [
        116.0,
        91.0,
        81.0,
        58.0,
        56.0,
        49.0,
        48.0,
        47.0,
        45.0,
        42.0,
        41.0,
        40.0,
        38.0,
        37.0,
        37.0,
        -36.0,
        -35.0,
        -28.0,
        -21.0,
        -20.0,
        -19.0,
        -16.0,
        -14.0,
        -14.0,
        -12.0,
        -11.0,
        -10.0,
        -9.0,
        -9.0,
        -9.0 ]

})

# %%
job_AI
# Out:
#                                      Occupation Title  \
# 0                                 Big Data Specialist
# 1                                   FinTech Engineers
# 2                  AI and Machine Learning Specialist
# 3                 Software and Application Developers
# 4                     Security Management Specialists
# 5                        Data Warehousing Specialists
# 6         Autonomous and Electric Vehicle Specialists
# 7                                 UI and UX Designers
# 8             Light Truck or Delivery Service Drivers
# 9                      Internet of Things Specialists
# 10                       Data Analysts and Scientists
# 11                            Environmental Engineers
# 12                      Information Security Analysts
# 13                                   Develop Engineer
# 14                         Renewable Energy Engineers
# 15                              Postal Service Clerks
# ...

# %%
noc_gender_mapping ={
    'Management occupations': {'Males percent': 64.6, 'Females percent': 35.4},
    'Business, finance and administration occupations': {'Males percent': 32.3, 'Females percent': 67.7},
    'Natural and applied sciences and related occupations': {'Males percent': 75.6, 'Females percent': 24.4},
    'Health occupations': {'Males percent': 20.6, 'Females percent': 79.4},
    'Occupations in education, law and social, community and government services': {'Males percent': 30.6, 'Females percent': 69.4},
    'Occupations in art, culture, recreation and sport': {'Males percent': 46.7, 'Females percent': 53.3},
    'Sales and service occupations': {'Males percent': 45.1, 'Females percent': 54.9},
    'Trades, transport and equipment operators and related occupations': {'Males percent': 92.6, 'Females percent': 7.4 },
    'Natural resources, agriculture and related production occupations': {'Males percent': 81.8, 'Females percent': 18.2},
    'Occupations in manufacturing and utilities': {'Males percent': 72.1, 'Females percent': 27.9}
}

job_AI['NOC Category'] = job_AI['Occupation Title'].map({
    'Big Data Specialist' : 'Natural and applied sciences and related occupations',
    'FinTech Engineers': 'Natural and applied sciences and related occupations',
    'AI and Machine Learning Specialist': 'Natural and applied sciences and related occupations',
    'Software and Application Developers': 'Natural and applied sciences and related occupations',
    'Data Warehousing Specialists': 'Natural and applied sciences and related occupations',
    'Security Management Specialists': 'Natural and applied sciences and related occupations',
    'UI and UX Designers': 'Natural and applied sciences and related occupations',
    'Internet of Things Specialists': 'Natural and applied sciences and related occupations',
    'Data Analysts and Scientists': 'Natural and applied sciences and related occupations',
    'Environmental Engineers': 'Natural and applied sciences and related occupations',
    'Information Security Analysts': 'Natural and applied sciences and related occupations',
    'Develop Engineer': 'Natural and applied sciences and related occupations',
    'Renewable Energy Engineers': 'Natural and applied sciences and related occupations',

    'Bank Tellers and Related Clerks': 'Business, finance and administration occupations',
    'Data Entry Clerks': 'Business, finance and administration occupations',
    'Administrative Assistants and Executive Secretaries': 'Business, finance and administration occupations',
    'Accounting, Bookkeeping and Payroll Clerks': 'Business, finance and administration occupations',

    'Light Truck or Delivery Service Drivers': 'Trades, transport and equipment operators and related occupations',
    'Autonomous and Electric Vehicle Specialists': 'Trades, transport and equipment operators and related occupations',
    'Printing and Related Trades Workers': 'Trades, transport and equipment operators and related occupations',
    'Material-Recording and Stock-Keeping Clerks': 'Trades, transport and equipment operators and related occupations',
    'Transportation Attendants and Conductors': 'Trades, transport and equipment operators and related occupations',

     'Postal Service Clerks': 'Sales and service occupations',
    'Cashiers and Ticket Clerks': 'Sales and service occupations',
    'Door-To-Door Sales Workers': 'Sales and service occupations',
    'Telemarketers': 'Sales and service occupations',

    'Graphic Designers': 'Occupations in art, culture, recreation and sport',

    'Claims Adjusters, Examiners and Investigators': 'Occupations in education, law and social, community and government services',
    'Legal Officials': 'Occupations in education, law and social, community and government services',
    'Legal Secretaries': 'Occupations in education, law and social, community and government services'


})

# %%
job_AI = job_AI.drop(columns = ['NOC Category'], axis =1)

# %%
job_AI
# Out:
#                                      Occupation Title  \
# 0                                 Big Data Specialist
# 1                                   FinTech Engineers
# 2                  AI and Machine Learning Specialist
# 3                 Software and Application Developers
# 4                     Security Management Specialists
# 5                        Data Warehousing Specialists
# 6         Autonomous and Electric Vehicle Specialists
# 7                                 UI and UX Designers
# 8             Light Truck or Delivery Service Drivers
# 9                      Internet of Things Specialists
# 10                       Data Analysts and Scientists
# 11                            Environmental Engineers
# 12                      Information Security Analysts
# 13                                   Develop Engineer
# 14                         Renewable Energy Engineers
# 15                              Postal Service Clerks
# ...

# %%
#Mapping Job Title to NOC Category
title_to_noc ={
   'Big Data Specialist': "Natural and applied sciences and related occupations"
}
job_AI['NOC Category'] = job_AI['Occupation Title'].map(title_to_noc)

# %%
job_AI
# Out:
#                                      Occupation Title  \
# 0                                 Big Data Specialist
# 1                                   FinTech Engineers
# 2                  AI and Machine Learning Specialist
# 3                 Software and Application Developers
# 4                     Security Management Specialists
# 5                        Data Warehousing Specialists
# 6         Autonomous and Electric Vehicle Specialists
# 7                                 UI and UX Designers
# 8             Light Truck or Delivery Service Drivers
# 9                      Internet of Things Specialists
# 10                       Data Analysts and Scientists
# 11                            Environmental Engineers
# 12                      Information Security Analysts
# 13                                   Develop Engineer
# 14                         Renewable Energy Engineers
# 15                              Postal Service Clerks
# ...

# %%
def get_female_percent(category):
  if category in noc_gender_mapping:
    return noc_gender_mapping[category]['Females percent']
  else:
      return None

def get_male_percent(category):
  if category in noc_gender_mapping:
    return noc_gender_mapping[category]['Males percent']
  else:
    return None


job_AI['Male percentage'] = job_AI['NOC Category'].apply(get_male_percent)
job_AI['Female percentage'] = job_AI['NOC Category'].apply(get_female_percent)


job_AI
# Out:
#                                      Occupation Title  \
# 0                                 Big Data Specialist
# 1                                   FinTech Engineers
# 2                  AI and Machine Learning Specialist
# 3                 Software and Application Developers
# 4                     Security Management Specialists
# 5                        Data Warehousing Specialists
# 6         Autonomous and Electric Vehicle Specialists
# 7                                 UI and UX Designers
# 8             Light Truck or Delivery Service Drivers
# 9                      Internet of Things Specialists
# 10                       Data Analysts and Scientists
# 11                            Environmental Engineers
# 12                      Information Security Analysts
# 13                                   Develop Engineer
# 14                         Renewable Energy Engineers
# 15                              Postal Service Clerks
# ...

# %%
diversity_mapping = {
    'Data processing, hosting, and related services': {'Total employed': 236, 'White': 68.7, 'Black or African American': 10.6, 'Asian': 15.5, 'Hispanic or Latino': 10.5 },
    'Computer systems design and related services': {'Total employed': 4091, 'White': 76.0, 'Black or African American': 8.2, 'Asian': 24.9, 'Hispanic or Latino': 8.1},
    'Computer systems design and related services': {'Total employed': 4091, 'White': 63.8, 'Black or African American': 8.2, 'Asian': 24.9, 'Hispanic or Latino': 8.1},
    'Computer systems design and related services': {'Total employed': 4091, 'White': 63.8, 'Black or African American': 8.2, 'Asian': 24.9, 'Hispanic or Latino': 8.1},
    'Investigation and security services': {'Total employed':926, 'White': 62.3, 'Black or African American': 29.1, 'Asian': 4.1, 'Hispanic or Latino': 19.1},
    'Computer systems design and related services': {'Total employed': 4091, 'White': 63.8, 'Black or African American': 8.2, 'Asian': 24.9, 'Hispanic or Latino': 8.1},
    'Transportation equipment manufacturing': {'Total employed': 2670, 'White': 76.3, 'Black or African American': 13.3, 'Asian': 7.2, 'Hispanic or Latino': 14.1},
    'Specialized design services': {'Total employed': 442, 'White': 81.6, 'Black or African American': 6.5, 'Asian': 8.0, 'Hispanic or Latino': 12.3},
    'Truck transportation': {'Total employed': 2076, 'White': 70.3, 'Black or African American': 21.1, 'Asian': 5.5, 'Hispanic or Latino': 23.1},
    'Computer systems design and related services': {'Total employed': 4091, 'White': 63.8, 'Black or African American': 8.2, 'Asian': 24.9, 'Hispanic or Latino': 8.1},
    'Computer systems design and related services': {'Total employed': 4091, 'White': 63.8, 'Black or African American': 8.2, 'Asian': 24.9, 'Hispanic or Latino': 8.1},
    'Architectural, engineering, and related services': {'Total employed': 1844, 'White':83.6, 'Black or African American': 6.8,'Asian':7.1, 'Hispanic or Latino':11.7 },
    'Investigation and security services': {'Total employed':926, 'White': 62.3, 'Black or African American': 29.1, 'Asian': 4.1, 'Hispanic or Latino':	19.1},
    'Computer systems design and related services': {'Total employed': 4091, 'White': 63.8, 'Black or African American': 8.2, 'Asian': 24.9, 'Hispanic or Latino': 8.1},
    'Architectural, engineering, and related services': {'Total employed': 1844, 'White':83.6, 'Black or African American': 6.8,'Asian':7.1, 'Hispanic or Latino':11.7 },
    'Postal Service': {'Total employed': 625, 'White': 61.5, 'Black or African American': 27.2, 'Asian': 7.1, 'Hispanic or Latino': 10.4  },
    'Banking and related activities': {'Total employed': 1982, 'White': 72.8, 'Black or African American': 13.4, 'Asian': 10.6, 'Hispanic or Latino':	11.9},
    'Management, administrative, and waste services': {'Total employed': 6768, 'White': 77.2, 'Black or African American':	14.8, 'Asian':3.5, 'Hispanic or Latino':32.3 	},
    'Retail trade': {'Total employed': 16327, 'White': 76.7, 'Black or African American': 12.6, 'Asian': 6.5, 'Hispanic or Latino': 19.8},
    'Executive offices and legislative bodies': {'Total employed': 1401, 'White': 70.2, 'Black or African American': 17.4, 'Asian': 5.6, 'Hispanic or Latino': 14.1},
    'Printing and related support activities': {'Total employed': 427, 'White': 83.4, 'Black or African American': 8.7, 'Asian': 6.9, 'Hispanic or Latino':18.3},
    'Accounting, tax preparation, bookkeeping, and payroll services': {'Total employed': 1350	, 'White': 80.8, 'Black or African American': 7.9	, 'Asian': 9.0, 'Hispanic or Latino':12.6},
    'Warehousing and storage': {'Total employed': 1128, 'White': 67.6	, 'Black or African American': 23.4	, 'Asian': 5.0, 'Hispanic or Latino': 37.7},
    'Rail transportation': {'Total employed': 210	, 'White': 78.0		, 'Black or African American': 16.2	, 'Asian': 2.3, 'Hispanic or Latino': 10.9},
    'Other direct selling establishments': {'Total employed': 66	, 'White': 84.6		, 'Black or African American': 10.4		, 'Asian': 3.3, 'Hispanic or Latino': 21.9},
    'Specialized design services': {'Total employed': 442, 'White': 81.6, 'Black or African American': 6.5, 'Asian': 8.0, 'Hispanic or Latino': 12.3},
    'Insurance carriers and related activities': {'Total employed': 2873, 'White': 77.4	, 'Black or African American': 14.7	, 'Asian': 5.7	, 'Hispanic or Latino': 12.8},
    'Legal services': {'Total employed': 1688	, 'White': 83.1	, 'Black or African American': 8.4	, 'Asian': 5.7	, 'Hispanic or Latino': 14.0},
    'Legal services': {'Total employed': 1688	, 'White': 83.1	, 'Black or African American': 8.4	, 'Asian': 5.7	, 'Hispanic or Latino': 14.0},
    'Administrative and support services': {'Total employed': 6768	, 'White': 77.2	, 'Black or African American': 14.8	, 'Asian': 3.5	, 'Hispanic or Latino': 32.3}





}

# %%
job_AI['Labor Statistics'] = job_AI['Occupation Title'].map({
    'Big Data Specialist': 'Data processing, hosting, and related services',
    'FinTech Engineers' :'Computer systems design and related services',
    'AI and Machine Learning Specialist' : 'Computer systems design and related services',
    'Software and Application Developers': 'Computer systems design and related services',
    'Security Management Specialists':  'Investigation and security services',
    'Data Warehousing Specialists':	 'Computer systems design and related services',
    'Autonomous and Electric Vehicle Specialists': 'Transportation equipment manufacturing',
    'UI and UX Designers': 'Specialized design services',
    'Light Truck or Delivery Service Drivers': 'Truck transportation',
    'Internet of Things Specialists':  'Computer systems design and related services',
    'Data Analysts and Scientists':  'Computer systems design and related services',
    'Environmental Engineers': 'Architectural, engineering, and related services',
    'Information Security Analysts': 'Investigation and security services',
    'Develop Engineer': 'Computer systems design and related services',
    'Renewable Energy Engineers': 'Architectural, engineering, and related services',
    'Postal Service Clerks': 'Postal Service',
    'Bank Tellers and Related Clerks': 'Banking and related activities',
    'Data Entry Clerks': 'Management, administrative, and waste services',
    'Cashiers and Ticket Clerks': 'Retail trade',
    'Administrative Assistants and Executive Secretaries':  'Executive offices and legislative bodies',
    'Printing and Related Trades Workers': 'Printing and related support activities',
    'Accounting, Bookkeeping and Payroll Clerks': 'Accounting, tax preparation, bookkeeping, and payroll services',
    'Material-Recording and Stock-Keeping Clerks' : 'Warehousing and storage',
    'Transportation Attendants and Conductors': 'Rail transportation',
    'Door-To-Door Sales Workers':  'Other direct selling establishments',
    'Graphic Designers': 'Specialized design services',
    'Claims Adjusters, Examiners and Investigators': 'Insurance carriers and related activities',
    'Legal Officials': 'Legal services',
    'Legal Secretaries':  'Legal services',
    'Telemarketers': 'Administrative and support services',

})

# %%
job_AI
# Out:
#                                      Occupation Title  \
# 0                                 Big Data Specialist
# 1                                   FinTech Engineers
# 2                  AI and Machine Learning Specialist
# 3                 Software and Application Developers
# 4                     Security Management Specialists
# 5                        Data Warehousing Specialists
# 6         Autonomous and Electric Vehicle Specialists
# 7                                 UI and UX Designers
# 8             Light Truck or Delivery Service Drivers
# 9                      Internet of Things Specialists
# 10                       Data Analysts and Scientists
# 11                            Environmental Engineers
# 12                      Information Security Analysts
# 13                                   Develop Engineer
# 14                         Renewable Energy Engineers
# 15                              Postal Service Clerks
# ...

# %%
  def get_White(category):
    if category in diversity_mapping:
      return diversity_mapping[category]['White']

  def get_Black(category):
    if category in diversity_mapping:
      return diversity_mapping[category]['Black or African American']

  def get_Asian(category):
    if category in diversity_mapping:
      return diversity_mapping[category]['Asian']

  def get_Latino(category):
    if category in diversity_mapping:
      return diversity_mapping[category]['Hispanic or Latino']

# %%
job_AI['White In Percentage'] = job_AI['Labor Statistics'].apply(get_White)
job_AI['Black In Percentage'] = job_AI['Labor Statistics'].apply(get_Black)
job_AI['Asian In Percentage'] = job_AI['Labor Statistics'].apply(get_Asian)
job_AI['Hispanic or Latino In Percentage'] = job_AI['Labor Statistics'].apply(get_Latino)

# %%
job_AI = job_AI.fillna('Missing Data')

# %%
job_AI
# Out:
#                                      Occupation Title  \
# 0                                 Big Data Specialist
# 1                                   FinTech Engineers
# 2                  AI and Machine Learning Specialist
# 3                 Software and Application Developers
# 4                     Security Management Specialists
# 5                        Data Warehousing Specialists
# 6         Autonomous and Electric Vehicle Specialists
# 7                                 UI and UX Designers
# 8             Light Truck or Delivery Service Drivers
# 9                      Internet of Things Specialists
# 10                       Data Analysts and Scientists
# 11                            Environmental Engineers
# 12                      Information Security Analysts
# 13                                   Develop Engineer
# 14                         Renewable Energy Engineers
# 15                              Postal Service Clerks
# ...

# %%
#Output as CSV
job_AI.to_csv('Job_AI_CSV')

# %% [markdown]
# **JOB INDUSTRY AFFECTED BY AI BASED ON AIOE SCORE**

# %%
industry_AI = pd.DataFrame({
    'Industry': [
        'Health care and social assistance',
        'Retail trade',
        'Manufacturing',
        'Educational services',
        'Accommodation and food services',
        'Public administration',
        'Professional, scientific and technical services',
        'Construction',
        'Finance and insurance',
        'Transportation and warehousing',
        'Wholesale trade',
        'Other services (except public administration)',
        'Administrative and support, waste management and remediation services',
        'Information and cultural industries',
        'Arts, entertainment and recreation',
        'Real estate and rental and leasing',
        'Mining, quarrying, and oil and gas extraction',
        'Agriculture, forestry, fishing and hunting',
        'Utilities',
        'Management of companies and enterprises',

    ],

    'Employment number':[
        1955500,
        1549400	,
        1295400,
        1091300,
        663800,
        1025900,
        1045200,
        958000	,
        661500,
        671700,
        498000,
        468000,
        499400,
        318100,
        157000,
        169800,
        194600,
        192300,
        136800	,
        38300],

    'AIOE': [
        6.0762,
        6.0176,
        5.9164,
        6.3759,
        5.7734,
        6.2976,
        6.4585,
        5.7966,
        6.5431,
        5.8772,
        6.1463,
        6.0246,
        5.9396,
        6.3207,
        6.0105,
        6.2870,
        5.9483,
        5.7126,
        6.1356	,
        6.5039


    ],

    'High exposure, low complementarity (percent)': [
        23,
        37,
        16,
        23,
        7	,
        45,
        57,
        13,
        68,
        19,
        33,
        26,
        39,
        56,
        25,
        36,
        16,
        12,
        26,
        59


    ],

    'High exposure, high complementarity (percent)': [
       38,
       23,
       20,
       69	,
       4	,
       31	,
       35	,
       14	,
       30	,
       15	,
       33,
       21	,
       14	,
       32	,
       29	,
       42	,
       25	,
       10	,
       34	,
       36




    ],

    'Low exposure (percent)': [
        39,
        40,
        64,
        8,
        89,
        24,
        8,
       73,
       2,
       66,
       34 ,
        53,
        47,
        12,
        46,
        22,
        59,
        78,
        40,
        5





    ],






})

# %%
industry_AI
# Out:
#                                              Industry  Employment number  \
# 0                   Health care and social assistance            1955500
# 1                                        Retail trade            1549400
# 2                                       Manufacturing            1295400
# 3                                Educational services            1091300
# 4                     Accommodation and food services             663800
# 5                               Public administration            1025900
# 6     Professional, scientific and technical services            1045200
# 7                                        Construction             958000
# 8                               Finance and insurance             661500
# 9                      Transportation and warehousing             671700
# 10                                    Wholesale trade             498000
# 11      Other services (except public administration)             468000
# ...

# %%
industry_AI = industry_AI.reset_index(drop = True)
industry_AI.to_excel('industry_AI.xlsx', sheet_name = 'IndustryAI', index= False)

# %% [markdown]
# **ADOPTION OF AI IN CANADIAN FIRMS**

# %%
region_AI = pd.DataFrame({
    'Region': [
        'Alberta',
        'Atlantic & Territories',
        'BC',
        'Manitoba',
        'Ontario',
        'Québec',
        'Saskatchewan',
        'Total Region'
    ],

    '% of companies that have adopted AI (percent)':[
        3,
        2,
        4,
        2,
        4,
        5,
        4,
        4
    ]
})

# %%
region_AI = region_AI.reset_index(drop = True)
region_AI.to_excel('regionAI.xlsx', sheet_name = 'Region AI')

# %% [markdown]
# **Gender Gaps IN NOC**

# %%
gender_gap = pd.DataFrame({
    'Management occupations': {'Males percent': 64.6, 'Females percent': 35.4},
    'Business, finance and administration occupations': {'Males percent': 32.3, 'Females percent': 67.7},
    'Natural and applied sciences and related occupations': {'Males percent': 75.6, 'Females percent': 24.4},
    'Health occupations': {'Males percent': 20.6, 'Females percent': 79.4},
    'Occupations in education, law and social, community and government services': {'Males percent': 30.6, 'Females percent': 69.4},
    'Occupations in art, culture, recreation and sport': {'Males percent': 46.7, 'Females percent': 53.3},
    'Sales and service occupations': {'Males percent': 45.1, 'Females percent': 54.9},
    'Trades, transport and equipment operators and related occupations': {'Males percent': 92.6, 'Females percent': 7.4},
    'Natural resources, agriculture and related production occupations': {'Males percent': 81.8, 'Females percent': 18.2},
    'Occupations in manufacturing and utilities': {'Males percent': 72.1, 'Females percent': 27.9}
}).T  # Transpose to get occupations as rows

# %%
gender_gap
# Out:
#                                                     Males percent  \
# Management occupations                                       64.6
# Business, finance and administration occupations             32.3
# Natural and applied sciences and related occupa...           75.6
# Health occupations                                           20.6
# Occupations in education, law and social, commu...           30.6
# Occupations in art, culture, recreation and sport            46.7
# Sales and service occupations                                45.1
# Trades, transport and equipment operators and r...           92.6
# Natural resources, agriculture and related prod...           81.8
# Occupations in manufacturing and utilities                   72.1
#
#                                                     Females percent
# Management occupations                                         35.4
# Business, finance and administration occupations               67.7
# ...

# %%
gender_gap.to_excel('gender_gap.xlsx', sheet_name = 'Gender Gap')

# %%
race_distribution = pd.DataFrame({
    'Finance and Insurance': {'White': 75.5, 'Black or African American': 12.6, 'Asian': 9.2, 'Hispanic or Latino': 11.1},
    'Management of companies and enterprises': {'White': 74.0, 'Black or African American': 7.1, 'Asian': 16.2, 'Hispanic or Latino':6.6},
    'Professional and technical services': {'White': 75.5, 'Black or African American': 8.2, 'Asian':13.2, 'Hispanic or Latino': 10.9 },
    'Educational services': {'White': 78.5, 'Black or African American': 11.9	, 'Asian': 6.0, 'Hispanic or Latino': 13.7 },
    'Information' : {'White': 75.2, 'Black or African American': 10.8, 'Asian': 10.1, 'Hispanic or Latino': 12.9 },
    'Real estate and rental and leasing': {'White': 79.3, 'Black or African American': 11.3, 'Asian': 5.8, 'Hispanic or Latino': 16.3	 },
    'Public administration': {'White': 71.6, 'Black or African American': 18.5, 'Asian': 5.2, 'Hispanic or Latino': 14.0 },
    'Wholesale trade': {'White': 82.1, 'Black or African American': 9.0, 'Asian': 6.2, 'Hispanic or Latino': 20.2   },
    'Health care and social assistance': {'White': 70.1, 'Black or African American': 18.3, 'Asian':7.8	, 'Hispanic or Latino': 15.3   },
    'Retail trade': {'White': 76.7	, 'Black or African American': 12.6	, 'Asian':6.5	, 'Hispanic or Latino': 19.8  },
    'Utilities': {'White': 82.0		, 'Black or African American': 7.8	, 'Asian':5.5		, 'Hispanic or Latino': 14.6  },
    'Arts, entertainment, and recreation': {'White': 79.4		, 'Black or African American': 10.4	, 'Asian': 4.7, 'Hispanic or Latino': 16.1  },
    'Administrative and support services': {'White': 77.2		, 'Black or African American': 14.8	, 'Asian': 3.5, 'Hispanic or Latino': 32.3 },
    'Waste management and remediation services': {'White': 82.9		, 'Black or African American': 11.2		, 'Asian': 2.8	, 'Hispanic or Latino': 28.2 },
    'Waste management and remediation services': {'White': 82.9		, 'Black or African American': 11.2		, 'Asian': 2.8	, 'Hispanic or Latino': 28.2 },
    'Other services': {'White': 77.2		, 'Black or African American': 11.4		, 'Asian': 7.6	, 'Hispanic or Latino': 20.7},
    'Mining, quarrying, and oil and gas extraction': {'White': 86.8		, 'Black or African American': 5.2		, 'Asian': 3.0	, 'Hispanic or Latino': 22.7},
    'Manufacturing': {'White': 77.8		, 'Black or African American': 11.2			, 'Asian': 7.7	, 'Hispanic or Latino': 18.3},
    'Transportation and warehousing': {'White': 66.7, 'Black or African American': 22.5	, 'Asian': 6.8	, 'Hispanic or Latino': 23.1},
    'Construction': {'White': 87.3, 'Black or African American': 6.5	, 'Asian': 2.1	, 'Hispanic or Latino': 35.1},
    'Agriculture, forestry, fishing, and hunting': {'White': 92.3, 'Black or African American': 3.1	, 'Asian': 1.1	, 'Hispanic or Latino': 24.9},
    'Accommodation and food services': {'White': 73.9	, 'Black or African American': 12.9	, 'Asian': 7.5	, 'Hispanic or Latino': 30.1},

}).T

# %%
race_distribution
# Out:
#                                                White  \
# Finance and Insurance                           75.5
# Management of companies and enterprises         74.0
# Professional and technical services             75.5
# Educational services                            78.5
# Information                                     75.2
# Real estate and rental and leasing              79.3
# Public administration                           71.6
# Wholesale trade                                 82.1
# Health care and social assistance               70.1
# Retail trade                                    76.7
# Utilities                                       82.0
# Arts, entertainment, and recreation             79.4
# Administrative and support services             77.2
# Waste management and remediation services       82.9
# Other services                                  77.2
# Mining, quarrying, and oil and gas extraction   86.8
# Manufacturing                                   77.8
# ...

# %%
race_distribution.to_excel('race_distribution.xlsx', sheet_name = 'Race')
